# %%
import pymongo
import sys
import importlib
import pandas as pd
sys.path.append(r'C:\Users\Bouchra\Documents\Master\S2\noSQL\project\ScraperExample-master')

# %%
import dao.mongodb_dao
importlib.reload(dao.mongodb_dao)
from dao.mongodb_dao import MongoDbDao

# %%
import app_config

# %% [markdown]
# # Retrieve Data from MongoDB database, and filter out NaNs

# %%
mongo_dao = MongoDbDao(app_config.db_conn_string)

# %%
df = mongo_dao.get_df_from_db(collection_name=app_config.collection_name, no_id=False)

# %%
df.head()
# Out:
#                         _id  \
# 0  5ec03ea16926074480c54f6d
# 1  5ec03ea16926074480c54f6e
# 2  5ec03ea16926074480c54f6f
# 3  5ec03ea16926074480c54f70
# 4  5ec03ea16926074480c54f71
#
#                                                  url  \
# 0  https://www.bbc.com/news/uk-northern-ireland-5...
# 1       https://www.bbc.com/news/explainers-52544307
# 2  https://www.bbc.com/news/newsbeat-52556784?int...
# 3  https://www.bbc.com/news/world-latin-america-5...
# 4  https://www.bbc.com/news/world-latin-america-5...
#
#                                                title  \
# 0  Coronavirus: NI being eased 'back to normality...
# 1  Coronavirus: What are the new travel quarantin...
# 2  Eurovision: How coronavirus changed the 2020 s...
# 3  Coronavirus: Crew on virus-hit cruise ship all...
# 4  Dozens dead in Mexico after drinking adulterat...
#
#                                                 body    published    tag_text  \
# 0  The executive is working to ease Northern Irel...  15 May 2020  N. Ireland
# 1  A two-week quarantine period for people arrivi...  15 May 2020  Explainers
# 2  Back in February, James Newman stepped onto a ...  11 May 2020    Newsbeat
# 3  Crew members from the coronavirus-hit cruise s...  13 May 2020       World
# 4  Police in Mexico are searching for the source ...  13 May 2020       World
#
#    year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020

# %%
df
# Out:
#                            _id  \
# 0     5ec03ea16926074480c54f6d
# 1     5ec03ea16926074480c54f6e
# 2     5ec03ea16926074480c54f6f
# 3     5ec03ea16926074480c54f70
# 4     5ec03ea16926074480c54f71
# ...                        ...
# 1046  5ec03ea16926074480c55383
# 1047  5ec03ea16926074480c55384
# 1048  5ec03ea16926074480c55385
# 1049  5ec03ea16926074480c55386
# 1050  5ec03ea16926074480c55387
#
#                                                     url  \
# 0     https://www.bbc.com/news/uk-northern-ireland-5...
# 1          https://www.bbc.com/news/explainers-52544307
# 2     https://www.bbc.com/news/newsbeat-52556784?int...
# 3     https://www.bbc.com/news/world-latin-america-5...
# 4     https://www.bbc.com/news/world-latin-america-5...
# ...                                                 ...
# 1046  https://www.bbc.com/news/uk-england-somerset-5...
# 1047      https://www.bbc.com/news/uk-politics-52606981
# 1048               https://www.bbc.com/news/uk-52626822
# 1049  https://www.bbc.com/news/uk-england-nottingham...
# 1050  https://www.bbc.com/news/uk-england-somerset-5...
#
#                                                   title  \
# 0     Coronavirus: NI being eased 'back to normality...
# 1     Coronavirus: What are the new travel quarantin...
# 2     Eurovision: How coronavirus changed the 2020 s...
# 3     Coronavirus: Crew on virus-hit cruise ship all...
# 4     Dozens dead in Mexico after drinking adulterat...
# ...                                                 ...
# 1046  Coronavirus: Holburne Museum sets £50k fundrai...
# 1047   Coronavirus: Job losses 'break my heart' - Sunak
# 1048  Coronavirus: PM 'not expecting' flood of peopl...
# 1049  VE Day: The enemy soldiers left in Britain aft...
# 1050  VE Day: Plea to name Somerset road after WWII ...
#
#                                                    body      published  \
# 0     The executive is working to ease Northern Irel...    15 May 2020
# 1     A two-week quarantine period for people arrivi...    15 May 2020
# 2     Back in February, James Newman stepped onto a ...    11 May 2020
# 3     Crew members from the coronavirus-hit cruise s...    13 May 2020
# 4     Police in Mexico are searching for the source ...    13 May 2020
# ...                                                 ...            ...
# 1046  A 130-year-old art museum at risk of permanent...  19 April 2020
# 1047  Chancellor Rishi Sunak has spoken of the "hear...    12 May 2020
# 1048  A "sudden big flood" of people returning to wo...    11 May 2020
# 1049  The parties and bunting of VE Day marked the e...     8 May 2020
# 1050  A petition has been set up to have a road name...     7 May 2020
#
#         tag_text  year
# 0     N. Ireland  2020
# 1     Explainers  2020
# 2       Newsbeat  2020
# 3          World  2020
# 4          World  2020
# ...          ...   ...
# 1046     England  2020
# 1047    Politics  2020
# 1048          UK  2020
# 1049     England  2020
# 1050     England  2020
#
# [1051 rows x 7 columns]

# %%
df = df[['tag_text', 'body']]

# %%
filtered_df = df[df['body'].apply(lambda x: len(x) > 0)]

# %%
len(filtered_df)
# Out:
# 1051

# %% [markdown]
# # Firstly, add category_id to each row, and create mapping dictionaries

# %%
filtered_df['category_id'] = filtered_df['tag_text'].factorize()[0]

# %%
category_id_df = filtered_df[['tag_text', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'tag_text']].values)

# %% [markdown]
# # Check distributions with bar chart

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
filtered_df.groupby('tag_text')['body'].count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# # Apply TfidfVectorizer: Term-Frequency Inverse Document Frequency
# - Scoring words on each document, give higher scores on frequent words on the specific category (Term-Frequency), weight down on words that are used on whole documents (Inverse Document Frequency)
# - The result of fit_transform is features that contains Tfidf scores of words.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(filtered_df['article_text']).toarray()
labels = filtered_df.category_id
features.shape
# Out:
# (421, 18089)

# %% [markdown]
# # Apply Chi-square to features to select terms with two highest scores

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for tag, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(tag))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Africa':
#   . Most correlated unigrams:
# . afp
# . epa
#   . Most correlated bigrams:
# . images afp
# . selection week
# # 'Business':
#   . Most correlated unigrams:
# . employers
# . assistant
#   . Most correlated bigrams:
# . digital assistant
# . domestic workers
# # 'Culture':
#   . Most correlated unigrams:
# . chintz
# . museum
#   . Most correlated bigrams:
# . american beetles
# . bbc culture
# # 'Did you miss?':
#   . Most correlated unigrams:
# . television
# . petriglieri
#   . Most correlated bigrams:
# . says petriglieri
# . watching television
# # 'Entertainment & Arts':
#   . Most correlated unigrams:
# . demos
# . charli
#   . Most correlated bigrams:
# . charli xcx
# . oh god
# # 'Europe':
#   . Most correlated unigrams:
# . brother
# . miguel
#   . Most correlated bigrams:
# . cristina carrasco
# . miguel sánchez
# # 'European Football':
#   . Most correlated unigrams:
# . finish
# . federation
#   . Most correlated bigrams:
# . teams europe
# . inter milan
# # 'Follow the Food':
#   . Most correlated unigrams:
# . cummings
# . exhausting
#   . Most correlated bigrams:
# . hours definitely
# . orders chicago
# # 'Food':
#   . Most correlated unigrams:
# . sourdough
# . starter
#   . Most correlated bigrams:
# . daily water
# . sourdough starter
# # 'Football':
#   . Most correlated unigrams:
# . everton
# . league
#   . Most correlated bigrams:
# . fa cup
# . premier league
# # 'Future':
#   . Most correlated unigrams:
# . capes
# . miracle
#   . Most correlated bigrams:
# . overlooked superheroes
# . people farmers
# # 'Future Planet':
#   . Most correlated unigrams:
# . red
# . sea
#   . Most correlated bigrams:
# . saudi arabia
# . climate change
# # 'Health':
#   . Most correlated unigrams:
# . labs
# . units
#   . Most correlated bigrams:
# . tests day
# . 100 000
# # 'In Pictures':
#   . Most correlated unigrams:
# . photographers
# . document
#   . Most correlated bigrams:
# . photographs courtesy
# . 24 photographers
# # 'News':
#   . Most correlated unigrams:
# . theme
# . keil
#   . Most correlated bigrams:
# . endanger unnecessary
# . risks infringe
# # 'Radio 4':
#   . Most correlated unigrams:
# . somebody
# . dyeing
#   . Most correlated bigrams:
# . dyeing things
# . look giving
# # 'Science & Environment':
#   . Most correlated unigrams:
# . emissions
# . climate
#   . Most correlated bigrams:
# . climate change
# . green deal
# # 'Sport':
#   . Most correlated unigrams:
# . bowl
# . tampa
#   . Most correlated bigrams:
# . tampa bay
# . super bowl
# # 'Technology':
#   . Most correlated unigrams:
# . devices
# . bluetooth
#   . Most correlated bigrams:
# . privacy international
# . bluetooth devices
# # 'Tennis':
#   . Most correlated unigrams:
# . racquet
# . rubin
#   . Most correlated bigrams:
# . lower ranked
# . ranked players
# # 'Travel':
#   . Most correlated unigrams:
# . lava
# . etna
#   . Most correlated bigrams:
# . south etna
# . bbc travel
# # 'UK':
#   . Most correlated unigrams:
# . worst
# . ppe
#   . Most correlated bigrams:
# . protective equipment
# . health secretary
# # 'US & Canada':
#   . Most correlated unigrams:
# . pharmacies
# . cuomo
#   . Most correlated bigrams:
# . cuomo said
# . mr cuomo
# # 'Worklife':
#   . Most correlated unigrams:
# . aircraft
# . airlines
#   . Most correlated bigrams:
# . design daniel
# . john walton
# # 'World':
#   . Most correlated unigrams:
# . treated
# . affect
#   . Most correlated bigrams:
# . affect treated
# . coronavirus affect

# %% [markdown]
# # Multi-Class Classifier: Features and Design
# - To train supervised classifiers, we first transformed the “article_text” into a vector of numbers. We explored vector representations such as TF-IDF weighted vectors.
# - After having this vector representations of the text we can train supervised classifiers to train unseen “article_text” and predict the “tag_text” on which they fall.
#
# After all the above data transformation, now that we have all the features and labels, it is time to train the classifiers. There are a number of algorithms we can use for this type of problem.
#
# - Naive Bayes Classifier: the one most suitable for word counts is the multinomial variant:

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(filtered_df['article_text'], filtered_df['tag_text'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform([filtered_df['article_text'].iloc[5]])))
# Out:
# ['Africa']

# %%
filtered_df['tag_text'].iloc[5]
# Out:
# 'Football'

# %% [markdown]
# # Model Selection
# We are now ready to experiment with different machine learning models, evaluate their accuracy and find the source of any potential issues.
#
# We will benchmark the following four models:
#
# - Logistic Regression
# - (Multinomial) Naive Bayes
# - Linear Support Vector Machine
# - Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# c:\users\bouchra\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# c:\users\bouchra\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# c:\users\bouchra\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# c:\users\bouchra\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.948039
# LogisticRegression        0.926835
# MultinomialNB             0.931541
# RandomForestClassifier    0.587059
# Name: accuracy, dtype: float64

# %% [markdown]
# # Proceed with the best model
# - Obtain confusion matrix to check the accuracy with heatmap

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, filtered_df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df['tag_text'].values, yticklabels=category_id_df['tag_text'].values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# # Check mis-predicted data

# %%
from IPython.display import display
for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if (actual >= len(conf_mat)) or (predicted >= conf_mat.shape[1]):
        continue
    if predicted != actual and conf_mat[actual, predicted] >= 3:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(filtered_df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['tag_text', 'article_text']])
      print('')
# Out:
# 'Leicester' predicted as 'Cricket' : 3 examples.
# Empty DataFrame
# Columns: [tag_text, article_text]
# Index: []
# 'Technology' predicted as 'Reel' : 3 examples.
# Empty DataFrame
# Columns: [tag_text, article_text]
# Index: []
# 'Science & Environment' predicted as 'Reel' : 3 examples.
# Empty DataFrame
# Columns: [tag_text, article_text]
# Index: []

# %% [markdown]
# # Check top unigrams and bigrams with the chosen model

# %%
model = LinearSVC()
model.fit(features, labels)
N = 2
for tag, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(tag))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'Africa':
#   . Top unigrams:
#        . reuters
#        . photos
#   . Top bigrams:
#        . world week
#        . want make
# # 'Arts':
#   . Top unigrams:
#        . ultimate
#        . magazine
#   . Top bigrams:
#        . things like
#        . don like
# # 'Asia':
#   . Top unigrams:
#        . chinese
#        . saying
#   . Top bigrams:
#        . human rights
#        . vice president
# # 'Australia':
#   . Top unigrams:
#        . australian
#        . melbourne
#   . Top bigrams:
#        . media reported
#        . earlier month
# # 'BBC Three':
#   . Top unigrams:
#        . drinking
#        . surrounded
#   . Top bigrams:
#        . bbc travel
#        . 10 years
# # 'Business':
#   . Top unigrams:
#        . business
#        . company
#   . Top bigrams:
#        . says mr
#        . chief executive
# # 'Capital':
#   . Top unigrams:
#        . class
#        . jobs
#   . Top bigrams:
#        . bbc capital
#        . capital head
# # 'Cricket':
#   . Top unigrams:
#        . cricket
#        . test
#   . Top bigrams:
#        . south africa
#        . bbc sport
# # 'Culture':
#   . Top unigrams:
#        . cinema
#        . films
#   . Top bigrams:
#        . bbc culture
#        . language films
# # 'Designed':
#   . Top unigrams:
#        . sky
#        . spectacular
#   . Top bigrams:
#        . like comment
#        . culture head
# # 'Earth':
#   . Top unigrams:
#        . reference
#        . 18
#   . Top bigrams:
#        . says mr
#        . making sure
# # 'England':
#   . Top unigrams:
#        . trick
#        . storm
#   . Top bigrams:
#        . police said
#        . said ve
# # 'Entertainment & Arts':
#   . Top unigrams:
#        . bbcnewsents
#        . suggestion
#   . Top bigrams:
#        . bbcnewsents instagram
#        . news bbc
# # 'Europe':
#   . Top unigrams:
#        . french
#        . nazi
#   . Top bigrams:
#        . mr trump
#        . lot time
# # 'European Football':
#   . Top unigrams:
#        . goals
#        . champions
#   . Top bigrams:
#        . make sure
#        . nations league
# # 'Football':
#   . Top unigrams:
#        . knee
#        . league
#   . Top bigrams:
#        . second half
#        . nations league
# # 'Formula 1':
#   . Top unigrams:
#        . race
#        . prix
#   . Top bigrams:
#        . grand prix
#        . south korea
# # 'Future':
#   . Top unigrams:
#        . climate
#        . battle
#   . Top bigrams:
#        . climate change
#        . join 900
# # 'Good Food':
#   . Top unigrams:
#        . experienced
#        . incident
#   . Top bigrams:
#        . 20 years
#        . said want
# # 'Health':
#   . Top unigrams:
#        . cancer
#        . cells
#   . Top bigrams:
#        . years ago
#        . people uk
# # 'Ideas':
#   . Top unigrams:
#        . 2018
#        . 26
#   . Top bigrams:
#        . withdrawal agreement
#        . years later
# # 'In Pictures':
#   . Top unigrams:
#        . photographs
#        . belong
#   . Top bigrams:
#        . photographs taken
#        . world war
# # 'Latin America & Caribbean':
#   . Top unigrams:
#        . migrants
#        . mexico
#   . Top bigrams:
#        . latin america
#        . 000 people
# # 'Leicester':
#   . Top unigrams:
#        . cleared
#        . pilot
#   . Top bigrams:
#        . twitter instagram
#        . facebook twitter
# # 'Middle East':
#   . Top unigrams:
#        . coalition
#        . israel
#   . Top bigrams:
#        . prime minister
#        . told reporters
# # 'Motorsport':
#   . Top unigrams:
#        . photographers
#        . speed
#   . Top bigrams:
#        . social media
#        . grand prix
# # 'News':
#   . Top unigrams:
#        . association
#        . press
#   . Top bigrams:
#        . don think
#        . said don
# # 'Newsbeat':
#   . Top unigrams:
#        . box
#        . celebrities
#   . Top bigrams:
#        . bbc radio
#        . facebook twitter
# # 'Reel':
#   . Top unigrams:
#        . largely
#        . field
#   . Top bigrams:
#        . really good
#        . 29 march
# # 'Rugby League':
#   . Top unigrams:
#        . player
#        . investigation
#   . Top bigrams:
#        . police said
#        . world cup
# # 'Rugby Union':
#   . Top unigrams:
#        . ben
#        . george
#   . Top bigrams:
#        . south africa
#        . 20 years
# # 'Science & Environment':
#   . Top unigrams:
#        . scientists
#        . dr
#   . Top bigrams:
#        . said dr
#        . bbc news
# # 'Sport':
#   . Top unigrams:
#        . gallery
#        . check
#   . Top bigrams:
#        . photographs taken
#        . world week
# # 'Stories':
#   . Top unigrams:
#        . danger
#        . couldn
#   . Top bigrams:
#        . 10 years
#        . feel like
# # 'Technology':
#   . Top unigrams:
#        . tech
#        . company
#   . Top bigrams:
#        . york times
#        . 20 years
# # 'Tennis':
#   . Top unigrams:
#        . djokovic
#        . serve
#   . Top bigrams:
#        . semi finals
#        . quarter final
# # 'Top Gear':
#   . Top unigrams:
#        . reference
#        . 18
#   . Top bigrams:
#        . says mr
#        . 10 years
# # 'Travel':
#   . Top unigrams:
#        . money
#        . live
#   . Top bigrams:
#        . bbc travel
#        . travel fans
# # 'UK':
#   . Top unigrams:
#        . alcohol
#        . drinking
#   . Top bigrams:
#        . lot people
#        . pleaded guilty
# # 'UK Politics':
#   . Top unigrams:
#        . eu
#        . ministers
#   . Top bigrams:
#        . uk eu
#        . cabinet ministers
# # 'US':
#   . Top unigrams:
#        . election
#        . trump
#   . Top bigrams:
#        . mid term
#        . los angeles
# # 'US & Canada':
#   . Top unigrams:
#        . trump
#        . senator
#   . Top bigrams:
#        . white house
#        . saudi arabia
# # 'World':
#   . Top unigrams:
#        . happening
#        . investigators
#   . Top bigrams:
#        . new york
#        . saudi arabia

# %%
# y_test could have missing ids if the number of samples is not sufficiently big.
def find_missing_idx(idx_series, whole_ids):
    total_num = len(whole_ids.unique())
    missing_numbers = [x for x in range(0, total_num) if x not in idx_series.unique()]
    return missing_numbers

# %%
from sklearn import metrics
# target_names_list = filtered_df['tag_text'].unique()
missing_ids = find_missing_idx(y_test, filtered_df['tag_text'])
target_names_list = category_id_df[~category_id_df['category_id'].isin(missing_ids)]['tag_text'].tolist()
target_labels_list = category_id_df[~category_id_df['category_id'].isin(missing_ids)]['category_id'].tolist()
print(metrics.classification_report(y_test, y_pred, target_names=target_names_list, labels=target_labels_list))
# Out:
#                            precision    recall  f1-score   support
#
#                Technology       0.50      0.20      0.29         5
#                    Future       1.00      0.67      0.80         3
#                    Travel       0.67      1.00      0.80         2
#                     World       0.00      0.00      0.00         1
#     Science & Environment       0.71      0.83      0.77         6
#                      Asia       0.00      0.00      0.00         5
#                  Football       1.00      1.00      1.00         7
#                   Cricket       1.00      1.00      1.00         2
#                      Reel       0.40      0.67      0.50         6
#                 Australia       0.50      0.40      0.44         5
#                  Business       0.27      1.00      0.42         4
#                   Culture       1.00      0.33      0.50         3
#                   Capital       0.75      1.00      0.86         6
#                 BBC Three       0.00      0.00      0.00         1
#                  Designed       1.00      1.00      1.00         1
#      Entertainment & Arts       0.83      1.00      0.91         5
#                    Health       0.00      0.00      0.00         1
#               In Pictures       0.67      1.00      0.80         4
# Latin America & Caribbean       1.00      0.50      0.67         2
#                 Leicester       0.00      0.00      0.00         1
#                        UK       0.00      0.00      0.00         1
#         European Football       1.00      1.00      1.00         1
#                    Europe       1.00      0.25      0.40         8
#               US & Canada       0.50      0.50      0.50         2
#               UK Politics       0.67      1.00      0.80         2
#                        US       0.00      0.00      0.00         1
#                 Formula 1       1.00      0.50      0.67         2
#                     Earth       0.00      0.00      0.00         1
#               Middle East       1.00      1.00      1.00         1
#                Motorsport       1.00      1.00      1.00         1
#                      News       0.00      0.00      0.00         1
#
#                 micro avg       0.64      0.62      0.63        91
#                 macro avg       0.56      0.54      0.52        91
#              weighted avg       0.65      0.62      0.58        91
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
